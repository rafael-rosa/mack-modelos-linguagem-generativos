# %% [markdown]
# <a href="https://colab.research.google.com/github/rafael-rosa/mack-modelos-linguagem-generativos/blob/main/movie_review_classif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# ## PROJETO FINAL DA DISCIPLINA ***MODELOS DE LINGUAGEM E GENERATIVOS***
# #### Prof. Rogério de Oliveira
# Alunos:
# + `Gildo Manzi da Silva - RA: 10329658`
# + `Rafael da Silva Rosa - RA: 10746329`
# + `Rogério Goussain Labat - RA: 10746326`
#
# #### 🎬 Objetivo: Identificar o gênero de um filme a partir de seu plot (trama) 🎭
# #### 📊 Origem dos dados: **IMDB (IDs dos filmes) e OMDB (API para consulta de Plots)**

# %% [markdown]
# ## 1️⃣ SETUP

# %%
# !pip install --upgrade pip
# !pip install -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt
# !pip install -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt
# Out:
# Requirement already satisfied: pip in c:\dev\python\wks\.venv\lib\site-packages (25.3)
# Requirement already satisfied: pandas==2.3.3 in c:\dev\python\wks\.venv\lib\site-packages (from -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: transformers==4.57.1 in c:\dev\python\wks\.venv\lib\site-packages (from -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (4.57.1)
# Requirement already satisfied: tf-keras==2.20.1 in c:\dev\python\wks\.venv\lib\site-packages (from -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (2.20.1)
# Requirement already satisfied: kagglehub in c:\dev\python\wks\.venv\lib\site-packages (from -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 4)) (0.3.13)
# Requirement already satisfied: scikit-learn==1.7.2 in c:\dev\python\wks\.venv\lib\site-packages (from -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 5)) (1.7.2)
# Requirement already satisfied: hf_xet==1.2.0 in c:\dev\python\wks\.venv\lib\site-packages (from -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: accelerate>=0.26.0 in c:\dev\python\wks\.venv\lib\site-packages (from -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 7)) (1.11.0)
# Requirement already satisfied: evaluate==0.4.6 in c:\dev\python\wks\.venv\lib\site-packages (from -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: numpy>=1.26.0 in c:\dev\python\wks\.venv\lib\site-packages (from pandas==2.3.3->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\dev\python\wks\.venv\lib\site-packages (from pandas==2.3.3->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\dev\python\wks\.venv\lib\site-packages (from pandas==2.3.3->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\dev\python\wks\.venv\lib\site-packages (from pandas==2.3.3->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: filelock in c:\dev\python\wks\.venv\lib\site-packages (from transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\dev\python\wks\.venv\lib\site-packages (from transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in c:\dev\python\wks\.venv\lib\site-packages (from transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\dev\python\wks\.venv\lib\site-packages (from transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\dev\python\wks\.venv\lib\site-packages (from transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (2025.11.3)
# Requirement already satisfied: requests in c:\dev\python\wks\.venv\lib\site-packages (from transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\dev\python\wks\.venv\lib\site-packages (from transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\dev\python\wks\.venv\lib\site-packages (from transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\dev\python\wks\.venv\lib\site-packages (from transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\dev\python\wks\.venv\lib\site-packages (from tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (2.20.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\dev\python\wks\.venv\lib\site-packages (from scikit-learn==1.7.2->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 5)) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\dev\python\wks\.venv\lib\site-packages (from scikit-learn==1.7.2->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 5)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\dev\python\wks\.venv\lib\site-packages (from scikit-learn==1.7.2->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: datasets>=2.0.0 in c:\dev\python\wks\.venv\lib\site-packages (from evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (4.4.1)
# Requirement already satisfied: dill in c:\dev\python\wks\.venv\lib\site-packages (from evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (0.4.0)
# Requirement already satisfied: xxhash in c:\dev\python\wks\.venv\lib\site-packages (from evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: multiprocess in c:\dev\python\wks\.venv\lib\site-packages (from evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (0.70.18)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\dev\python\wks\.venv\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\dev\python\wks\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (6.33.1)
# Requirement already satisfied: setuptools in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (3.12.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\dev\python\wks\.venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\dev\python\wks\.venv\lib\site-packages (from requests->transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\dev\python\wks\.venv\lib\site-packages (from requests->transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\dev\python\wks\.venv\lib\site-packages (from requests->transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\dev\python\wks\.venv\lib\site-packages (from requests->transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\dev\python\wks\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (3.10)
# Requirement already satisfied: pillow in c:\dev\python\wks\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\dev\python\wks\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\dev\python\wks\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (3.1.3)
# Requirement already satisfied: psutil in c:\dev\python\wks\.venv\lib\site-packages (from accelerate>=0.26.0->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 7)) (7.1.3)
# Requirement already satisfied: torch>=2.0.0 in c:\dev\python\wks\.venv\lib\site-packages (from accelerate>=0.26.0->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 7)) (2.8.0+cu129)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\dev\python\wks\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (0.45.1)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\dev\python\wks\.venv\lib\site-packages (from datasets>=2.0.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (22.0.0)
# Requirement already satisfied: httpx<1.0.0 in c:\dev\python\wks\.venv\lib\site-packages (from datasets>=2.0.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\dev\python\wks\.venv\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (3.13.2)
# Requirement already satisfied: anyio in c:\dev\python\wks\.venv\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (4.11.0)
# Requirement already satisfied: httpcore==1.* in c:\dev\python\wks\.venv\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\dev\python\wks\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\dev\python\wks\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\dev\python\wks\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\dev\python\wks\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\dev\python\wks\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\dev\python\wks\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\dev\python\wks\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\dev\python\wks\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (1.22.0)
# Requirement already satisfied: rich in c:\dev\python\wks\.venv\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (14.2.0)
# Requirement already satisfied: namex in c:\dev\python\wks\.venv\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (0.1.0)
# Requirement already satisfied: optree in c:\dev\python\wks\.venv\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (0.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\dev\python\wks\.venv\lib\site-packages (from torch>=2.0.0->accelerate>=0.26.0->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: networkx in c:\dev\python\wks\.venv\lib\site-packages (from torch>=2.0.0->accelerate>=0.26.0->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 7)) (3.5)
# Requirement already satisfied: jinja2 in c:\dev\python\wks\.venv\lib\site-packages (from torch>=2.0.0->accelerate>=0.26.0->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\dev\python\wks\.venv\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=0.26.0->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: colorama in c:\dev\python\wks\.venv\lib\site-packages (from tqdm>=4.27->transformers==4.57.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\dev\python\wks\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in c:\dev\python\wks\.venv\lib\site-packages (from anyio->httpx<1.0.0->datasets>=2.0.0->evaluate==0.4.6->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\dev\python\wks\.venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\dev\python\wks\.venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\dev\python\wks\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras==2.20.1->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/requirements.txt (line 3)) (0.1.2)
# Looking in indexes: https://download.pytorch.org/whl/cu129
# Requirement already satisfied: torch in c:\dev\python\wks\.venv\lib\site-packages (from -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 2)) (2.8.0+cu129)
# Requirement already satisfied: torchvision in c:\dev\python\wks\.venv\lib\site-packages (from -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 3)) (0.23.0+cu129)
# Requirement already satisfied: torchaudio in c:\dev\python\wks\.venv\lib\site-packages (from -r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 4)) (2.8.0+cu129)
# Requirement already satisfied: filelock in c:\dev\python\wks\.venv\lib\site-packages (from torch->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 2)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\dev\python\wks\.venv\lib\site-packages (from torch->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\dev\python\wks\.venv\lib\site-packages (from torch->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx in c:\dev\python\wks\.venv\lib\site-packages (from torch->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 2)) (3.5)
# Requirement already satisfied: jinja2 in c:\dev\python\wks\.venv\lib\site-packages (from torch->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec in c:\dev\python\wks\.venv\lib\site-packages (from torch->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 2)) (2025.10.0)
# Requirement already satisfied: setuptools in c:\dev\python\wks\.venv\lib\site-packages (from torch->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 2)) (80.9.0)
# Requirement already satisfied: numpy in c:\dev\python\wks\.venv\lib\site-packages (from torchvision->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\dev\python\wks\.venv\lib\site-packages (from torchvision->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 3)) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\dev\python\wks\.venv\lib\site-packages (from sympy>=1.13.3->torch->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\dev\python\wks\.venv\lib\site-packages (from jinja2->torch->-r https://raw.githubusercontent.com/rafael-rosa/mack-modelos-linguagem-generativos/main/other-requirements.txt (line 2)) (3.0.3)

# %% [markdown]
# #### 1️⃣.1️⃣ IMPORTS

# %%
import pandas as pd
import torch
import torch.nn as nn
from transformers import pipeline
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
import numpy as np
import evaluate
from ydata_profiling import ProfileReport
# Out:
# WARNING:tensorflow:From c:\dev\python\wks\.venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# #### 1️⃣.2️⃣ ENV VARIABLES

# %%
AMOUNT_OF_PLOTS_TO_CLASSIFY = 500
NUM_TRAIN_EPOCHS = 10 # Número de épocas para o fine-tuning
WARMUP_STEPS = 500 # Passos de aquecimento para o otimizador
WEIGHT_DECAY = 0.01 # Decaimento de peso para o otimizador
TRAIN_SAMPLE_SIZE = 1500 # Tamanho da amostra de treino
MODEL_CHECKPOINT = "distilbert-base-uncased" # modelo leve para o fine-tuning - DistilBERT - rápido de treinar e tem ótima performance.
DATASET = "movies_dataset\\movie_plots_dataset.csv"

# %% [markdown]
# #### 1️⃣.3️⃣ DATASET - IMDB MOVIE REVIEWS TO CLASSIFY

# %%
df = pd.read_csv(DATASET)    
# df.head(20)

# Delete column Unnamed: 0 if exists
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])

profile = ProfileReport(df, title="IMDB Dataset Profiling Report", explorative=True)
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00, 18.32it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-12-01 04:30:42.081991&quot; name=date&gt;&lt;title&gt;IMDB Dataset Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %%
# Get list of unique genres
unique_genres = df['genre'].unique().tolist()
print("Unique genres:", unique_genres)

NUMBER_OF_GENRES = len(unique_genres)
print("Number of unique genres:", NUMBER_OF_GENRES)

# Delete duplicated rows
df = df.drop_duplicates()
df.shape
# Out:
# Unique genres: ['DOCUMENTARY', 'COMEDY', 'DRAMA', 'SHORT', 'WESTERN', 'THRILLER', 'ANIMATION', 'MUSIC', 'CRIME', 'SCI-FI', 'HORROR', 'TALK-SHOW', 'FAMILY', 'ACTION', 'MYSTERY', 'BIOGRAPHY', 'REALITY-TV', 'NEWS', 'FANTASY', 'ROMANCE', 'MUSICAL', 'SPORT', 'HISTORY', 'GAME-SHOW', 'ADVENTURE', 'WAR', 'ADULT']
# Number of unique genres: 27
# (3057, 2)

# %% [markdown]
# #### 1️⃣.4️⃣ SET GPU CARD

# %%
# !nvidia-smi
print(f"GPU available? {'✅' if torch.cuda.is_available() else '❌'}")
print(f"GPU name: {'🎮 ' + torch.cuda.get_device_name(0) if torch.cuda.is_available() else '⚠️ None'}")

# Verify if the GPU (CUDA) is available
# If it is, use "cuda:0" (the first GPU)
# If not, use "cpu"
device = "cuda:0" if torch.cuda.is_available() else "cpu"

print(f"Selected device: 🖥️ {device}")
# Out:
# Mon Dec  1 01:30:43 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 577.00                 Driver Version: 577.00         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   47C    P8              1W /   60W |       0MiB /   6141MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# GPU available? ✅
# GPU name: 🎮 NVIDIA GeForce RTX 4050 Laptop GPU
# Selected device: 🖥️ cuda:0

# %%
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli",
                      device=device)   # Use GPU if available
# Out:
# Device set to use cuda:0

# %% [markdown]
# ## 2️⃣ Zero-Shot Classification
# #### 2️⃣.1️⃣ USE ***BART LARGE MNLI*** MODEL TO DETERMINE MOVIE GENRE

# %%
reviews = df['plot'][:AMOUNT_OF_PLOTS_TO_CLASSIFY].tolist()
print(f"Classifying {len(reviews)} plots...")

model_classification_results = []
candidate_labels = unique_genres

def data():
    for i in reviews:
        yield i

# Batch processing using the pipeline for efficiency
for result in classifier(data(), candidate_labels, batch_size=2):
    print("classification:", result['labels'][0], "with score", result['scores'][0])
    model_classification_results.append({
        'review': result['sequence'],
        'predicted_label': result['labels'][0],
        'score': result['scores'][0]
    })
# Out:
# Classifying 500 plots...
# classification: ADVENTURE with score 0.41323086619377136
# classification: ACTION with score 0.1754855364561081
# classification: FAMILY with score 0.4149571359157562
# classification: THRILLER with score 0.5509849786758423
# classification: ANIMATION with score 0.6133695244789124
# classification: MUSIC with score 0.1956285685300827
# classification: MYSTERY with score 0.6379823088645935
# classification: ACTION with score 0.14777158200740814
# classification: ACTION with score 0.2798418402671814
# classification: HISTORY with score 0.14951208233833313
# classification: NEWS with score 0.1462828516960144
# classification: DRAMA with score 0.1194235160946846
# classification: DOCUMENTARY with score 0.20527265965938568
# classification: MUSICAL with score 0.517494797706604
# classification: FAMILY with score 0.5148017406463623
# classification: DOCUMENTARY with score 0.7006697058677673
# classification: FAMILY with score 0.29807785153388977
# classification: DOCUMENTARY with score 0.590815007686615
# classification: ACTION with score 0.11376093327999115
# classification: CRIME with score 0.1833314150571823
# classification: MYSTERY with score 0.2600758373737335
# classification: FAMILY with score 0.6012476682662964
# classification: SHORT with score 0.12652654945850372
# classification: THRILLER with score 0.1632256656885147
# classification: ANIMATION with score 0.07631522417068481
# classification: FAMILY with score 0.3755616545677185
# classification: MYSTERY with score 0.1902891993522644
# classification: ACTION with score 0.1500687152147293
# classification: ACTION with score 0.19859381020069122
# classification: FAMILY with score 0.17936129868030548
# classification: FAMILY with score 0.16689908504486084
# classification: ADVENTURE with score 0.2803371548652649
# classification: ACTION with score 0.16116920113563538
# classification: MYSTERY with score 0.5416494011878967
# classification: DRAMA with score 0.5087823867797852
# classification: ACTION with score 0.11075612902641296
# classification: WAR with score 0.23239678144454956
# classification: FAMILY with score 0.34483465552330017
# classification: FAMILY with score 0.18123099207878113
# classification: DOCUMENTARY with score 0.10676547884941101
# classification: ADVENTURE with score 0.3282076418399811
# classification: WAR with score 0.59413743019104
# classification: ACTION with score 0.208772674202919
# classification: MUSIC with score 0.3050258159637451
# classification: DRAMA with score 0.1638370156288147
# classification: WESTERN with score 0.27142056822776794
# classification: ACTION with score 0.20242954790592194
# classification: SHORT with score 0.695950448513031
# classification: FAMILY with score 0.3852795660495758
# classification: MYSTERY with score 0.4139590859413147
# classification: DOCUMENTARY with score 0.1337880641222
# classification: ACTION with score 0.24025900661945343
# classification: CRIME with score 0.2692398130893707
# classification: MUSIC with score 0.15838977694511414
# classification: ACTION with score 0.13139492273330688
# classification: ACTION with score 0.4643438458442688
# classification: ACTION with score 0.19663798809051514
# classification: ACTION with score 0.43869221210479736
# classification: MYSTERY with score 0.2693086266517639
# classification: MYSTERY with score 0.16110952198505402
# classification: FAMILY with score 0.2623356878757477
# classification: THRILLER with score 0.2563167214393616
# classification: ADVENTURE with score 0.26310887932777405
# classification: DOCUMENTARY with score 0.22989396750926971
# classification: COMEDY with score 0.15385092794895172
# classification: ACTION with score 0.20741671323776245
# classification: ACTION with score 0.2511536777019501
# classification: TALK-SHOW with score 0.7978243827819824
# classification: FAMILY with score 0.7279877066612244
# classification: SHORT with score 0.5610045194625854
# classification: FAMILY with score 0.32249757647514343
# classification: FAMILY with score 0.8212370276451111
# classification: FAMILY with score 0.27939721941947937
# classification: MYSTERY with score 0.13582882285118103
# classification: MUSIC with score 0.17358693480491638
# classification: ACTION with score 0.24524635076522827
# classification: MUSICAL with score 0.41785791516304016
# classification: THRILLER with score 0.5429275035858154
# classification: MUSICAL with score 0.277016282081604
# classification: ACTION with score 0.8066412806510925
# classification: HISTORY with score 0.17771701514720917
# classification: REALITY-TV with score 0.6023584604263306
# classification: CRIME with score 0.3945472240447998
# classification: ACTION with score 0.2554507255554199
# classification: ACTION with score 0.1869652271270752
# classification: DOCUMENTARY with score 0.30124324560165405
# classification: ADVENTURE with score 0.2714667320251465
# classification: HORROR with score 0.2795450687408447
# classification: SPORT with score 0.5653608441352844
# classification: FAMILY with score 0.2088889628648758
# classification: NEWS with score 0.2639671862125397
# classification: MYSTERY with score 0.29428571462631226
# classification: HORROR with score 0.19783923029899597
# classification: ACTION with score 0.2576274871826172
# classification: MYSTERY with score 0.47721952199935913
# classification: ADVENTURE with score 0.2561422288417816
# classification: ROMANCE with score 0.3287650942802429
# classification: FAMILY with score 0.4812958538532257
# classification: NEWS with score 0.10087986290454865
# classification: ACTION with score 0.7778411507606506
# classification: FAMILY with score 0.24207691848278046
# classification: ADVENTURE with score 0.15079012513160706
# classification: FAMILY with score 0.39807263016700745
# classification: ACTION with score 0.26809561252593994
# classification: HISTORY with score 0.41228750348091125
# classification: MUSIC with score 0.2470751851797104
# classification: DRAMA with score 0.18474726378917694
# classification: ACTION with score 0.280757874250412
# classification: DOCUMENTARY with score 0.42018362879753113
# classification: ACTION with score 0.33956602215766907
# classification: NEWS with score 0.17737703025341034
# classification: MUSIC with score 0.19894801080226898
# classification: DOCUMENTARY with score 0.15605522692203522
# classification: ACTION with score 0.12061119079589844
# classification: MUSIC with score 0.23874688148498535
# classification: ACTION with score 0.1126343384385109
# classification: MYSTERY with score 0.3376255929470062
# classification: ACTION with score 0.12074526399374008
# classification: ACTION with score 0.1634598821401596
# classification: DOCUMENTARY with score 0.8079158663749695
# classification: FAMILY with score 0.522754967212677
# classification: DOCUMENTARY with score 0.1368834525346756
# classification: ACTION with score 0.15212443470954895
# classification: HISTORY with score 0.1685689389705658
# classification: MUSIC with score 0.26893535256385803
# classification: FANTASY with score 0.3896075189113617
# classification: ANIMATION with score 0.16215232014656067
# classification: FAMILY with score 0.23205682635307312
# classification: DRAMA with score 0.1327713280916214
# classification: ACTION with score 0.31166210770606995
# classification: FAMILY with score 0.23033712804317474
# classification: THRILLER with score 0.12501433491706848
# classification: ACTION with score 0.08585771173238754
# classification: FAMILY with score 0.2514311373233795
# classification: ANIMATION with score 0.22684116661548615
# classification: CRIME with score 0.47391194105148315
# classification: ROMANCE with score 0.18468381464481354
# classification: ACTION with score 0.2592757046222687
# classification: DRAMA with score 0.6045118570327759
# classification: HORROR with score 0.3369918167591095
# classification: HORROR with score 0.4640209972858429
# classification: ADVENTURE with score 0.23542195558547974
# classification: ACTION with score 0.22892260551452637
# classification: HORROR with score 0.21765679121017456
# classification: DOCUMENTARY with score 0.8119246363639832
# classification: ACTION with score 0.14935430884361267
# classification: HORROR with score 0.38400745391845703
# classification: ACTION with score 0.15701280534267426
# classification: ACTION with score 0.3927680552005768
# classification: DOCUMENTARY with score 0.657447874546051
# classification: ANIMATION with score 0.17036621272563934
# classification: ACTION with score 0.1444900780916214
# classification: NEWS with score 0.4675215780735016
# classification: DOCUMENTARY with score 0.285176157951355
# classification: ACTION with score 0.10484635084867477
# classification: ACTION with score 0.15943001210689545
# classification: DRAMA with score 0.15316469967365265
# classification: FAMILY with score 0.17558197677135468
# classification: ADVENTURE with score 0.15518926084041595
# classification: ACTION with score 0.22804482281208038
# classification: CRIME with score 0.4828833341598511
# classification: CRIME with score 0.4098660945892334
# classification: ACTION with score 0.22471828758716583
# classification: CRIME with score 0.29338929057121277
# classification: CRIME with score 0.16842611134052277
# classification: NEWS with score 0.11976321041584015
# classification: CRIME with score 0.25502127408981323
# classification: ACTION with score 0.15005426108837128
# classification: NEWS with score 0.12425548583269119
# classification: DOCUMENTARY with score 0.15007562935352325
# classification: ACTION with score 0.5633684396743774
# classification: ACTION with score 0.1262977123260498
# classification: MYSTERY with score 0.23368071019649506
# classification: ACTION with score 0.24644212424755096
# classification: ADVENTURE with score 0.26461920142173767
# classification: DOCUMENTARY with score 0.15932098031044006
# classification: COMEDY with score 0.27472278475761414
# classification: HISTORY with score 0.4051727056503296
# classification: SHORT with score 0.16569316387176514
# classification: THRILLER with score 0.14220257103443146
# classification: THRILLER with score 0.16400550305843353
# classification: SPORT with score 0.12167796492576599
# classification: HORROR with score 0.15396401286125183
# classification: FANTASY with score 0.1861601620912552
# classification: HISTORY with score 0.2970368266105652
# classification: NEWS with score 0.15240459144115448
# classification: DOCUMENTARY with score 0.24672777950763702
# classification: WAR with score 0.42953798174858093
# classification: ACTION with score 0.16551168262958527
# classification: COMEDY with score 0.20297309756278992
# classification: ACTION with score 0.19360411167144775
# classification: NEWS with score 0.19631725549697876
# classification: ROMANCE with score 0.27354896068573
# classification: MUSIC with score 0.46580633521080017
# classification: FAMILY with score 0.5961259603500366
# classification: THRILLER with score 0.17418736219406128
# classification: HISTORY with score 0.6587772369384766
# classification: ACTION with score 0.2746272087097168
# classification: ACTION with score 0.16048474609851837
# classification: DOCUMENTARY with score 0.23913684487342834
# classification: ACTION with score 0.19121626019477844
# classification: ACTION with score 0.206548273563385
# classification: COMEDY with score 0.6672629117965698
# classification: ACTION with score 0.17156709730625153
# classification: WAR with score 0.45726698637008667
# classification: COMEDY with score 0.11600037664175034
# classification: HISTORY with score 0.10119420289993286
# classification: FAMILY with score 0.1939787119626999
# classification: HISTORY with score 0.19683818519115448
# classification: DOCUMENTARY with score 0.853449285030365
# classification: ADVENTURE with score 0.17122402787208557
# classification: ANIMATION with score 0.10942529886960983
# classification: FAMILY with score 0.1921524852514267
# classification: ACTION with score 0.21468736231327057
# classification: ACTION with score 0.2888217866420746
# classification: DOCUMENTARY with score 0.6752363443374634
# classification: ADVENTURE with score 0.391310453414917
# classification: ACTION with score 0.338030606508255
# classification: SHORT with score 0.1389639526605606
# classification: DOCUMENTARY with score 0.17256656289100647
# classification: ACTION with score 0.1194348856806755
# classification: ACTION with score 0.4686480760574341
# classification: SCI-FI with score 0.459310382604599
# classification: MUSICAL with score 0.4053848385810852
# classification: ACTION with score 0.12895485758781433
# classification: ROMANCE with score 0.7333201169967651
# classification: MYSTERY with score 0.31198158860206604
# classification: ACTION with score 0.20799238979816437
# classification: DOCUMENTARY with score 0.6601529121398926
# classification: DOCUMENTARY with score 0.8859013915061951
# classification: COMEDY with score 0.6539462208747864
# classification: ACTION with score 0.27201759815216064
# classification: ACTION with score 0.37700408697128296
# classification: ACTION with score 0.2964327037334442
# classification: MYSTERY with score 0.17761585116386414
# classification: NEWS with score 0.23090161383152008
# classification: MYSTERY with score 0.33547720313072205
# classification: ACTION with score 0.21728847920894623
# classification: GAME-SHOW with score 0.30647343397140503
# classification: SHORT with score 0.783470630645752
# classification: ACTION with score 0.17865034937858582
# classification: HORROR with score 0.7307806611061096
# classification: ACTION with score 0.22054621577262878
# classification: ANIMATION with score 0.15843565762043
# classification: MYSTERY with score 0.1584557145833969
# classification: CRIME with score 0.24376855790615082
# classification: ROMANCE with score 0.19875243306159973
# classification: FAMILY with score 0.26608192920684814
# classification: CRIME with score 0.15254561603069305
# classification: ACTION with score 0.18438570201396942
# classification: MYSTERY with score 0.09807246923446655
# classification: ROMANCE with score 0.07067114859819412
# classification: DOCUMENTARY with score 0.500025749206543
# classification: ACTION with score 0.3144076466560364
# classification: FAMILY with score 0.46199172735214233
# classification: MUSIC with score 0.40248072147369385
# classification: BIOGRAPHY with score 0.185543030500412
# classification: FAMILY with score 0.22068054974079132
# classification: CRIME with score 0.5531204342842102
# classification: ACTION with score 0.11993235349655151
# classification: FAMILY with score 0.42957934737205505
# classification: MYSTERY with score 0.4936930239200592
# classification: MUSICAL with score 0.11701995879411697
# classification: THRILLER with score 0.12105215340852737
# classification: FAMILY with score 0.2351522147655487
# classification: ACTION with score 0.23645099997520447
# classification: FAMILY with score 0.11383289098739624
# classification: MUSICAL with score 0.2615271210670471
# classification: CRIME with score 0.16906651854515076
# classification: ACTION with score 0.257856160402298
# classification: WAR with score 0.22271956503391266
# classification: ACTION with score 0.1399325132369995
# classification: ROMANCE with score 0.22359851002693176
# classification: ACTION with score 0.4114384949207306
# classification: MUSICAL with score 0.4491414427757263
# classification: HORROR with score 0.7119581699371338
# classification: ACTION with score 0.10771820694208145
# classification: DOCUMENTARY with score 0.08548253029584885
# classification: FAMILY with score 0.17722512781620026
# classification: DRAMA with score 0.4557553231716156
# classification: ACTION with score 0.23765014111995697
# classification: ACTION with score 0.14929401874542236
# classification: ADVENTURE with score 0.25744542479515076
# classification: ACTION with score 0.12524130940437317
# classification: CRIME with score 0.20281656086444855
# classification: FAMILY with score 0.23986245691776276
# classification: ADVENTURE with score 0.42126965522766113
# classification: WAR with score 0.25379031896591187
# classification: FAMILY with score 0.20438438653945923
# classification: ACTION with score 0.1666753739118576
# classification: MYSTERY with score 0.5913543105125427
# classification: ADVENTURE with score 0.06900978088378906
# classification: TALK-SHOW with score 0.20025430619716644
# classification: SPORT with score 0.34583643078804016
# classification: ACTION with score 0.3209114074707031
# classification: DOCUMENTARY with score 0.42613059282302856
# classification: ADVENTURE with score 0.21650320291519165
# classification: WAR with score 0.22376835346221924
# classification: COMEDY with score 0.36876294016838074
# classification: GAME-SHOW with score 0.7736101150512695
# classification: DRAMA with score 0.742516815662384
# classification: CRIME with score 0.4129761755466461
# classification: MYSTERY with score 0.17763952910900116
# classification: ACTION with score 0.1519048660993576
# classification: ACTION with score 0.30205145478248596
# classification: SHORT with score 0.7560301423072815
# classification: MYSTERY with score 0.24228760600090027
# classification: ACTION with score 0.19056563079357147
# classification: DOCUMENTARY with score 0.11901414394378662
# classification: ACTION with score 0.2618500292301178
# classification: SHORT with score 0.7039724588394165
# classification: COMEDY with score 0.6960244178771973
# classification: SHORT with score 0.1287670135498047
# classification: SHORT with score 0.23358404636383057
# classification: MUSICAL with score 0.25370028614997864
# classification: FAMILY with score 0.231572225689888
# classification: COMEDY with score 0.3106703460216522
# classification: SHORT with score 0.8357042670249939
# classification: ACTION with score 0.12875287234783173
# classification: MYSTERY with score 0.6156979203224182
# classification: DRAMA with score 0.7226943373680115
# classification: FAMILY with score 0.45065534114837646
# classification: DOCUMENTARY with score 0.15273576974868774
# classification: DOCUMENTARY with score 0.20213477313518524
# classification: FAMILY with score 0.3919491469860077
# classification: ADVENTURE with score 0.11597197502851486
# classification: ACTION with score 0.10902571678161621
# classification: CRIME with score 0.189079150557518
# classification: ACTION with score 0.3597104549407959
# classification: NEWS with score 0.14347892999649048
# classification: MYSTERY with score 0.4190514087677002
# classification: ADVENTURE with score 0.2272079437971115
# classification: ACTION with score 0.26080575585365295
# classification: FAMILY with score 0.41554519534111023
# classification: MYSTERY with score 0.10583249479532242
# classification: ACTION with score 0.1735079288482666
# classification: FANTASY with score 0.14491981267929077
# classification: ACTION with score 0.1397746205329895
# classification: ACTION with score 0.5650658011436462
# classification: FAMILY with score 0.6646541357040405
# classification: ROMANCE with score 0.060113344341516495
# classification: ADULT with score 0.57366544008255
# classification: FANTASY with score 0.244535431265831
# classification: ROMANCE with score 0.32635581493377686
# classification: NEWS with score 0.30193430185317993
# classification: MUSICAL with score 0.4639036953449249
# classification: ACTION with score 0.2590985596179962
# classification: SPORT with score 0.7036679983139038
# classification: ADULT with score 0.35809236764907837
# classification: ACTION with score 0.17310914397239685
# classification: ACTION with score 0.3559221625328064
# classification: ROMANCE with score 0.19579966366291046
# classification: CRIME with score 0.2031705677509308
# classification: CRIME with score 0.2942686080932617
# classification: ACTION with score 0.22606061398983002
# classification: ACTION with score 0.19301825761795044
# classification: COMEDY with score 0.8654487729072571
# classification: HISTORY with score 0.414016455411911
# classification: FAMILY with score 0.13754042983055115
# classification: TALK-SHOW with score 0.23186923563480377
# classification: DOCUMENTARY with score 0.1725214123725891
# classification: SHORT with score 0.12168185412883759
# classification: FAMILY with score 0.29199638962745667
# classification: NEWS with score 0.10981857031583786
# classification: THRILLER with score 0.16893303394317627
# classification: DOCUMENTARY with score 0.13134290277957916
# classification: COMEDY with score 0.3620217442512512
# classification: ACTION with score 0.15100449323654175
# classification: MYSTERY with score 0.3580012917518616
# classification: ACTION with score 0.38918250799179077
# classification: DRAMA with score 0.15088815987110138
# classification: FAMILY with score 0.4582999646663666
# classification: ACTION with score 0.3061007261276245
# classification: FAMILY with score 0.24648456275463104
# classification: SHORT with score 0.11279713362455368
# classification: SHORT with score 0.23525916039943695
# classification: FAMILY with score 0.21833868324756622
# classification: MYSTERY with score 0.4293917417526245
# classification: FAMILY with score 0.3122982084751129
# classification: COMEDY with score 0.17483364045619965
# classification: ACTION with score 0.25743764638900757
# classification: ACTION with score 0.3947925269603729
# classification: ROMANCE with score 0.2868731915950775
# classification: ACTION with score 0.1549442708492279
# classification: FAMILY with score 0.21885554492473602
# classification: FAMILY with score 0.5482239127159119
# classification: TALK-SHOW with score 0.24933487176895142
# classification: CRIME with score 0.15818539261817932
# classification: MUSIC with score 0.32745933532714844
# classification: MYSTERY with score 0.6051424741744995
# classification: FAMILY with score 0.3416241705417633
# classification: FAMILY with score 0.2082994431257248
# classification: ACTION with score 0.16410093009471893
# classification: ADVENTURE with score 0.2663782835006714
# classification: DOCUMENTARY with score 0.6234782338142395
# classification: FAMILY with score 0.4975365996360779
# classification: COMEDY with score 0.14053520560264587
# classification: MYSTERY with score 0.6785180568695068
# classification: DOCUMENTARY with score 0.17944186925888062
# classification: MUSIC with score 0.6161232590675354
# classification: HORROR with score 0.23020705580711365
# classification: HORROR with score 0.13106945157051086
# classification: ACTION with score 0.1491319239139557
# classification: HISTORY with score 0.5406315326690674
# classification: DOCUMENTARY with score 0.18024727702140808
# classification: THRILLER with score 0.18528690934181213
# classification: FAMILY with score 0.6683142781257629
# classification: MUSICAL with score 0.3398376703262329
# classification: DOCUMENTARY with score 0.47685709595680237
# classification: DOCUMENTARY with score 0.7451155781745911
# classification: FAMILY with score 0.20142729580402374
# classification: SHORT with score 0.9023783206939697
# classification: COMEDY with score 0.6250572204589844
# classification: NEWS with score 0.19937685132026672
# classification: MYSTERY with score 0.12664133310317993
# classification: FAMILY with score 0.6688970923423767
# classification: DOCUMENTARY with score 0.20373721420764923
# classification: MYSTERY with score 0.10433166474103928
# classification: DRAMA with score 0.7602440714836121
# classification: DRAMA with score 0.807529866695404
# classification: DRAMA with score 0.6347276568412781
# classification: CRIME with score 0.29832059144973755
# classification: THRILLER with score 0.20325040817260742
# classification: DOCUMENTARY with score 0.24070845544338226
# classification: COMEDY with score 0.4415853023529053
# classification: ACTION with score 0.14980898797512054
# classification: COMEDY with score 0.618921160697937
# classification: COMEDY with score 0.8384750485420227
# classification: THRILLER with score 0.14880387485027313
# classification: GAME-SHOW with score 0.7492331862449646
# classification: NEWS with score 0.2017226368188858
# classification: FAMILY with score 0.46737009286880493
# classification: FAMILY with score 0.32130518555641174
# classification: DOCUMENTARY with score 0.17650216817855835
# classification: COMEDY with score 0.10691314190626144
# classification: HORROR with score 0.125392347574234
# classification: ACTION with score 0.5310623645782471
# classification: DOCUMENTARY with score 0.8048240542411804
# classification: ACTION with score 0.3036765158176422
# classification: ACTION with score 0.1798068732023239
# classification: ACTION with score 0.30351367592811584
# classification: ACTION with score 0.19384483993053436
# classification: CRIME with score 0.3968774378299713
# classification: DOCUMENTARY with score 0.32664167881011963
# classification: NEWS with score 0.17987249791622162
# classification: FAMILY with score 0.3172452449798584
# classification: FAMILY with score 0.27429890632629395
# classification: FAMILY with score 0.20789577066898346
# classification: CRIME with score 0.13428911566734314
# classification: HORROR with score 0.33847159147262573
# classification: ACTION with score 0.10595760494470596
# classification: COMEDY with score 0.1764504611492157
# classification: ACTION with score 0.34406033158302307
# classification: FAMILY with score 0.5248104929924011
# classification: ACTION with score 0.23417624831199646
# classification: ACTION with score 0.5362865328788757
# classification: FAMILY with score 0.17681100964546204
# classification: SHORT with score 0.4003964960575104
# classification: ACTION with score 0.41522809863090515
# classification: HORROR with score 0.40654468536376953
# classification: ACTION with score 0.1225142851471901
# classification: ACTION with score 0.5922185778617859
# classification: MYSTERY with score 0.15316028892993927
# classification: ACTION with score 0.16824546456336975
# classification: ACTION with score 0.21278977394104004
# classification: HORROR with score 0.11466929316520691
# classification: ADVENTURE with score 0.44503137469291687
# classification: ACTION with score 0.6988695859909058
# classification: ACTION with score 0.09147584438323975
# classification: ACTION with score 0.37303033471107483
# classification: FANTASY with score 0.35205531120300293
# classification: ACTION with score 0.16858167946338654
# classification: ACTION with score 0.6232073307037354
# classification: ACTION with score 0.18405799567699432
# classification: NEWS with score 0.16095049679279327
# classification: DOCUMENTARY with score 0.27184590697288513
# classification: FAMILY with score 0.17424628138542175
# classification: DOCUMENTARY with score 0.21537984907627106
# classification: WAR with score 0.22932350635528564
# classification: FAMILY with score 0.23765769600868225
# classification: DRAMA with score 0.46158772706985474
# classification: CRIME with score 0.17042478919029236
# classification: ACTION with score 0.156594380736351
# classification: ACTION with score 0.13162842392921448
# classification: FAMILY with score 0.14644663035869598
# classification: ACTION with score 0.18100975453853607
# classification: ROMANCE with score 0.676419198513031
# classification: ACTION with score 0.14912058413028717
# classification: MYSTERY with score 0.397024929523468
# classification: SHORT with score 0.24004705250263214
# classification: ACTION with score 0.1875288039445877
# classification: HISTORY with score 0.21317026019096375
# classification: FAMILY with score 0.3157826066017151
# classification: ACTION with score 0.14281919598579407
# classification: ACTION with score 0.13012953102588654
# classification: CRIME with score 0.16225746273994446
# classification: FAMILY with score 0.3676787316799164
# classification: MUSIC with score 0.2783195674419403
# classification: HISTORY with score 0.10868451744318008
# classification: ACTION with score 0.152006596326828

# %% [markdown]
# #### 2️⃣.2️⃣ ERROR PERCENTAGE

# %%
counter_incorrect = 0
for index, row in df.head(AMOUNT_OF_PLOTS_TO_CLASSIFY).iterrows():
    predicted = model_classification_results[index]['predicted_label']
    actual_label = row['genre']
    if predicted != actual_label:
        # print(f"Plot {index+1} - Predicted: {predicted}, Actual: {actual_label}")
        counter_incorrect += 1
        
error_percentage = (counter_incorrect / AMOUNT_OF_PLOTS_TO_CLASSIFY) * 100
print(f"Total incorrect predictions: {counter_incorrect} - Error percentage: {error_percentage:.2f}%")
# Out:
# Total incorrect predictions: 426 - Error percentage: 85.20%

# %% [markdown]
# #### 2️⃣.3️⃣ METRICS - BASELINE

# %%
# 1. Obter os rótulos verdadeiros (ground truth)
true_labels = list(df.head(AMOUNT_OF_PLOTS_TO_CLASSIFY)['genre'])

# 2. Obter os rótulos previstos
predicted_labels = [item['predicted_label'] for item in model_classification_results]

# 3. Relatório de classificação
print("--- MÉTRICAS DO MODELO ZERO-SHOT (Baseline) ---")
print(classification_report(true_labels, predicted_labels, target_names=unique_genres))
# Out:
# --- MÉTRICAS DO MODELO ZERO-SHOT (Baseline) ---
#               precision    recall  f1-score   support
#
#  DOCUMENTARY       0.02      0.60      0.04         5
#       COMEDY       0.50      0.03      0.05        35
#        DRAMA       0.00      0.00      0.00         2
#        SHORT       0.00      0.00      0.00         7
#      WESTERN       0.00      0.00      0.00         1
#     THRILLER       0.68      0.14      0.23        96
#    ANIMATION       0.42      0.45      0.43        22
#        MUSIC       0.56      0.31      0.40        78
#        CRIME       0.67      0.07      0.13       139
#       SCI-FI       0.00      0.00      0.00         3
#       HORROR       0.00      0.00      0.00         3
#    TALK-SHOW       1.00      0.60      0.75         5
#       FAMILY       0.00      0.00      0.00         1
#       ACTION       0.00      0.00      0.00        11
#      MYSTERY       0.00      0.00      0.00         3
#    BIOGRAPHY       0.00      0.00      0.00         1
#   REALITY-TV       0.09      0.21      0.13        14
#         NEWS       0.00      0.00      0.00         1
#      FANTASY       1.00      0.07      0.13        14
#      ROMANCE       0.08      0.25      0.12         4
#      MUSICAL       0.00      0.00      0.00         2
#        SPORT       0.18      0.09      0.12        33
#      HISTORY       0.00      0.00      0.00         1
#    GAME-SHOW       0.25      0.33      0.29         3
#    ADVENTURE       0.00      0.00      0.00        12
#          WAR       0.12      1.00      0.22         1
#        ADULT       0.00      0.00      0.00         3
#
#     accuracy                           0.15       500
#    macro avg       0.21      0.15      0.11       500
# weighted avg       0.51      0.15      0.19       500

# %% [markdown]
# ## 3️⃣ FINE-TUNNING
# #### 3️⃣.1️⃣ DATA PREPARATION

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)

sample_df = df.sample(n=TRAIN_SAMPLE_SIZE, random_state=42) 

# Convert genre labels to numerical values
sample_df['label_num'] = sample_df['genre'].astype('category').cat.codes

# Split the data into Train and Test
X = list(sample_df['plot'])
y = list(sample_df['label_num'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Tokenize (convert text into numbers the model understands)
train_encodings = tokenizer(X_train, truncation=True, padding=True, max_length=256)
test_encodings = tokenizer(X_test, truncation=True, padding=True, max_length=256)

# %%
## Resolvebndo o desbalanceamento de Classes
## Loss Function Ponderada

# Calcula os pesos baseados na frequência das classes no treino
class_weights = compute_class_weight(
    class_weight="balanced", # classes raras ganham peso alto, classes comuns ganham peso baixo.
    classes=np.unique(y_train), 
    y=y_train
)

# Converte para Tensor do PyTorch e envia para a GPU
weights_tensor = torch.tensor(class_weights, dtype=torch.float).to(device)

print("Pesos das Classes:", weights_tensor)
# Out:
# Pesos das Classes: tensor([ 1.8519,  1.7544,  8.3333,  3.0303, 33.3333,  0.1984,  1.5152,  0.1684,
#          0.1481,  2.5641, 16.6667,  8.3333,  8.3333,  1.5152, 11.1111, 11.1111,
#          4.1667,  8.3333,  0.3831,  2.7778,  8.3333,  1.0101, 16.6667,  3.0303,
#          1.9608, 16.6667, 11.1111], device='cuda:0')

# %%
sample_df.head(10)
# Out:
#                                                    plot        genre  \
# 1765  THE FILM COMPANION TEAMS BRINGS YOU THE LATEST...    TALK-SHOW
# 203   WHEN LEIGHTON TURNS DOWN THE FREEZERS, IN A BI...       COMEDY
# 1357  IN HIDDEN BASEMENTS, BEDROOMS AND BARS ACROSS ...  DOCUMENTARY
# 1452  THE SALE OF THE STADIUM IS ON THE BALANCE. LUC...        DRAMA
# 1578       A JOURNEY THROUGH THE ART OF LOVE AND DEATH.  DOCUMENTARY
# 102   A FUNERAL BRINGS TOGETHER DIFFERENT SIDES OF D...        DRAMA
# 2838  A WIDOWED MOTHER TAKES A JOB AS AN OVERNIGHT S...     THRILLER
# 1819  SHE IS THE OCEAN - A FULL-LENGTH DOCUMENTARY A...  DOCUMENTARY
# 485   LIISA ARRIVES ON AN ISLAND TO SERVE AS A NURSE...        DRAMA
# 1437  IN THEIR FINAL CHALLENGE BEFORE FASHION WEEK, ...   REALITY-TV
#
#       label_num
# 1765         23
# 203           5
# 1357          7
# 1452          8
# 1578          7
# 102           8
# 2838         24
# 1819          7
# 485           8
# 1437         18

# %%
class IMDbDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        # Get all 'input_ids', 'attention_mask', etc.
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        # Add label
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = IMDbDataset(train_encodings, y_train)
test_dataset = IMDbDataset(test_encodings, y_test)

# %% [markdown]
# #### 3️⃣.2️⃣ TREINAMENTO

# %%
accuracy_metric = evaluate.load("accuracy")

# Used by trainer to compute metrics
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return accuracy_metric.compute(predictions=predictions, references=labels)

# Load the pre-trained model (with a classification "head" on top)
# The num_labels tells it to prepare to classify between the number of genres
model = AutoModelForSequenceClassification.from_pretrained(MODEL_CHECKPOINT, num_labels=NUMBER_OF_GENRES)

# Uma prática melhor é avaliar o modelo ao final de cada época e salvar apenas o melhor.
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=NUM_TRAIN_EPOCHS,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    warmup_steps=WARMUP_STEPS,
    weight_decay=WEIGHT_DECAY,
    logging_dir='./logs',
    logging_steps=10,
    eval_strategy="epoch",            # Avaliar a cada época
    save_strategy="epoch",            # Salvar a cada época
    load_best_model_at_end=True       # Carregar o melhor modelo no final
)

# trainer = Trainer(
#     model=model,
#     args=training_args,
#     train_dataset=train_dataset,
#     eval_dataset=test_dataset,
#     compute_metrics=compute_metrics
# )

# O Trainer padrão do Hugging Face não aceita pesos nativamente. Precisamos sobrescrever a função compute_loss
class WeightedTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, num_items_in_batch=None):
        # Extrai os labels e os outputs do modelo
        labels = inputs.get("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")
        
        # Definimos a função de erro CrossEntropy com os nossos pesos calculados
        loss_fct = nn.CrossEntropyLoss(weight=weights_tensor)
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        return (loss, outputs) if return_outputs else loss

trainer = WeightedTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='570' max='570' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [570/570 03:03, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.301600</td>
#       <td>3.280371</td>
#       <td>0.081667</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.294400</td>
#       <td>3.243977</td>
#       <td>0.163333</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.150300</td>
#       <td>3.163981</td>
#       <td>0.165000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.936100</td>
#       <td>3.054405</td>
#       <td>0.313333</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.675500</td>
#       <td>2.862642</td>
#       <td>0.406667</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.405200</td>
#       <td>2.703629</td>
#       <td>0.376667</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.836200</td>
#       <td>2.554795</td>
#       <td>0.438333</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.465600</td>
#       <td>2.332684</td>
#       <td>0.408333</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.801400</td>
#       <td>2.483413</td>
#       <td>0.491667</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.382500</td>
#       <td>2.454453</td>
#       <td>0.508333</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=570, training_loss=2.2584907109277292, metrics={'train_runtime': 184.0016, 'train_samples_per_second': 48.913, 'train_steps_per_second': 3.098, 'total_flos': 596369060352000.0, 'train_loss': 2.2584907109277292, 'epoch': 10.0})

# %% [markdown]
# ### 3️⃣.3️⃣ METRICS - AFTER FINE-TUNNING

# %%
# Make predictions on the test set
predictions = trainer.predict(test_dataset)

# Predictions come out as "logits", we need the final label (0 or 1)
predicted_labels_tuned = np.argmax(predictions.predictions, axis=1)

# Get the true labels from the test set
true_labels_tuned = y_test

# Generate the classification report
print("--- FINE-TUNED MODEL METRICS ---")
print(classification_report(true_labels_tuned, predicted_labels_tuned, target_names=unique_genres))
# Out:
# --- FINE-TUNED MODEL METRICS ---
#               precision    recall  f1-score   support
#
#  DOCUMENTARY       0.17      0.20      0.18         5
#       COMEDY       0.33      0.43      0.38        14
#        DRAMA       0.00      0.00      0.00         2
#        SHORT       0.00      0.00      0.00         6
#      WESTERN       0.00      0.00      0.00         1
#     THRILLER       0.52      0.52      0.52       123
#    ANIMATION       0.15      0.22      0.18         9
#        MUSIC       0.68      0.69      0.68       127
#        CRIME       0.43      0.09      0.15       133
#       SCI-FI       0.25      0.33      0.29         9
#       HORROR       0.00      0.00      0.00         2
#    TALK-SHOW       0.25      0.67      0.36         3
#       FAMILY       0.60      1.00      0.75         3
#       ACTION       0.28      0.45      0.34        22
#      MYSTERY       0.50      0.75      0.60         4
#    BIOGRAPHY       0.00      0.00      0.00         1
#   REALITY-TV       0.67      0.40      0.50         5
#         NEWS       1.00      0.25      0.40         4
#      FANTASY       0.55      0.35      0.43        51
#      ROMANCE       0.20      0.62      0.30        13
#      MUSICAL       0.00      0.00      0.00         1
#        SPORT       0.20      0.36      0.26        33
#      HISTORY       1.00      0.25      0.40         4
#    GAME-SHOW       0.18      0.33      0.23         9
#    ADVENTURE       0.11      0.50      0.18        12
#          WAR       0.00      0.00      0.00         2
#        ADULT       0.50      0.50      0.50         2
#
#     accuracy                           0.41       600
#    macro avg       0.32      0.33      0.28       600
# weighted avg       0.47      0.41      0.40       600
# c:\dev\python\wks\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\dev\python\wks\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\dev\python\wks\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ## 4️⃣ CONCLUSÃO

# %% [markdown]
# Este projeto comparou duas abordagens de Processamento de Linguagem Natural (PLN) para a tarefa de **Classificação de Gênero de Filmes** baseada em sinopses (plots):
# 1.  **Zero-Shot Learning (Baseline):** Utilizando o modelo `facebook/bart-large-mnli` (406M parâmetros) sem nenhum treinamento prévio.
# 2.  **Transfer Learning & Fine-Tuning:** Utilizando o modelo `distilbert-base-uncased` (66M parâmetros), treinado especificamente neste dataset.
#
#
#
# ### Resultados:
#
# | MODELO | ESTRATÉGIA | MODELO BASE | ACURÁCIA | F1-SCORE (WEIGHTED) | TEMPO DE INFERÊNCIA |
# | -------- | -------- | ----------- | -------- | ------------------- | ------------------- |
# | Baseline | Zero-Shot | ***facebook/bart-large-mnli*** | **41%** | 0.41 | Alto (lento) |
# | Desafiante | Fine-Tuning | ***distilbert-base-uncased*** | **15%** | 0.15 | Baixo (Rápido) |
#
# ### Análise:
#
# A tarefa de classificação multiclasse expôs as limitações da abordagem Zero-Shot e a força do Fine-Tuning:
#
# 1.  **O Desafio da Ambiguidade:** Em um cenário com 27 classes possíveis, a fronteira entre gêneros como "Ação", "Aventura" e "Crime" é tênue. O modelo Zero-Shot, por ser generalista, tende a se confundir com a sobreposição de temas. O modelo Fine-Tuned, por outro lado, aprendeu as nuances específicas de como *este dataset* define cada gênero.
#
# 2.  **Eficiência Computacional:** A abordagem Zero-Shot exigiu que o modelo processasse cada sinopse comparando-a com todas as etiquetas candidatas, tornando a inferência significativamente mais lenta. O modelo Fine-Tuned (DistilBERT), além de ser arquiteturalmente mais leve (66M vs 406M parâmetros), realiza a classificação em uma única passagem direta (forward pass), sendo ideal para ambientes de produção.
#
# ### Veredito Final
# Para tarefas complexas de classificação multiclasse com definições de domínio específicas, o **Fine-Tuning é indispensável**. Embora o Zero-Shot seja uma ferramenta poderosa para prototipagem rápida e situações de "cold start" (sem dados), ele não consegue competir com a precisão e a eficiência de um modelo especialista treinado (mesmo que menor) quando dados rotulados estão disponíveis.
#
# ### Observação CPU x GPU
#
# O uso de GPU para execução do modelo **BART-Large** e treino do modelo **DistilBERT** apresentou uma redução no tempo de execução de 15 vezes frente ao uso de CPU para as mesmas tarefas. Isto deixa clara a importância do uso deste tipo de hardware no âmbito da NLI.
